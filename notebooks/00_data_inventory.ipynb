# %%
import pandas as pd
from pathlib import Path

data_dir = Path("../data/raw")

print("Files found in data/raw:")
for f in data_dir.iterdir():
    print("-", f.name)

# Load data_core.csv
core_path = data_dir / "data_core.csv"
core_df = pd.read_csv(core_path)
print("\n=== data_core.csv ===")
print("Shape:", core_df.shape)
display(core_df.head())

# Load India Agriculture Crop Production.csv
prod_path = data_dir / "India Agriculture Crop Production.csv"
prod_df = pd.read_csv(prod_path)
print("\n=== India Agriculture Crop Production.csv ===")
print("Shape:", prod_df.shape)
display(prod_df.head())
# Out:
# Files found in data/raw:
# - data_core.csv
# - India Agriculture Crop Production.csv
#
# === data_core.csv ===
# Shape: (8000, 9)
#    Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0         26.0      52.0      38.0     Sandy      Maize        37          0
# 1         29.0      52.0      45.0     Loamy  Sugarcane        12          0
# 2         34.0      65.0      62.0     Black     Cotton         7          9
# 3         32.0      62.0      34.0       Red    Tobacco        22          0
# 4         28.0      54.0      46.0    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea
# === India Agriculture Crop Production.csv ===
# Shape: (345407, 10)
#                          State                  District      Crop     Year  \
# ...

# %%
import pandas as pd

df1 = pd.read_csv("data/raw/data_core.csv")
print("data_core.csv shape:", df1.shape)
df1.head()
# Out:
# --------------------------------------------------------------
# FileNotFoundError            Traceback (most recent call last)
# Cell In[1], line 3
#       1 import pandas as pd
# ----> 3 df1 = pd.read_csv("data/raw/data_core.csv")
#       4 print("data_core.csv shape:", df1.shape)
#       5 df1.head()
#
# ...

# %%
import os
from pathlib import Path

print("Notebook cwd:", os.getcwd())
print("Notebook file:", Path().resolve())
print("\nListing data/ (if exists):")
print(os.listdir('.') if os.path.exists('.') else "no .")
print("\nListing data/raw (if exists):")
raw = Path("data/raw")
print("Exists:", raw.exists())
if raw.exists():
    print(sorted([p.name for p in raw.iterdir()]))
else:
    # try one level up (notebooks/ case)
    up = Path("..") / "data" / "raw"
    print("Try ../data/raw exists:", up.exists())
    if up.exists():
        print(sorted([p.name for p in up.iterdir()]))
# Out:
# Notebook cwd: D:\ZENITH_PROJ\zenith_project\notebooks
# Notebook file: D:\ZENITH_PROJ\zenith_project\notebooks
#
# Listing data/ (if exists):
# ['.ipynb_checkpoints', '00_data_inventory.ipynb']
#
# Listing data/raw (if exists):
# Exists: False
# Try ../data/raw exists: True
# ['India Agriculture Crop Production.csv', 'README.txt', 'data_core.csv']

# %%
df1 = pd.read_csv("../data/raw/data_core.csv")
print("shape:", df1.shape)
df1.head()
# Out:
# shape: (8000, 9)
#    Temparature  Humidity  Moisture Soil Type  Crop Type  Nitrogen  Potassium  \
# 0         26.0      52.0      38.0     Sandy      Maize        37          0
# 1         29.0      52.0      45.0     Loamy  Sugarcane        12          0
# 2         34.0      65.0      62.0     Black     Cotton         7          9
# 3         32.0      62.0      34.0       Red    Tobacco        22          0
# 4         28.0      54.0      46.0    Clayey      Paddy        35          0
#
#    Phosphorous Fertilizer Name
# 0            0            Urea
# 1           36             DAP
# 2           30        14-35-14
# 3           20           28-28
# 4            0            Urea
